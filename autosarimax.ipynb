# %%
# imports
import pandas as pd
#from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima

pd.options.display.max_columns = None

# %%
# read data
dtype = {'ID_LAT_LON_YEAR_WEEK':'string',
         'latitude': 'string',
         'longitude': 'string',
         'year': 'int',
         'week_no': 'int',
         'emission': 'float'}
df = pd.read_csv('files/train.csv', dtype=dtype)
df_test = pd.read_csv('files/test.csv', dtype=dtype)
# df

# %%
# prepare data
df['id'] = df['ID_LAT_LON_YEAR_WEEK'].str[:16]
day_of_week = {2019:2, 2020:3, 2021:5, 2022:6, 2023:0}
df.loc[:, 'day_of_week'] = df['year'].map(day_of_week)
df.loc[:, 'date'] = df['year'].astype('string') + '-' + df['week_no'].astype('string') + '-' + df['day_of_week'].astype('string')
df.loc[:, 'date'] = pd.to_datetime(df['date'], format='%Y-%W-%w')

df_test.insert(0, 'id', df_test['ID_LAT_LON_YEAR_WEEK'].str[:16])
# df

# %%
endog_groups = df[['id', 'date', 'emission']].groupby('id')

exog = df.drop(columns=['ID_LAT_LON_YEAR_WEEK', 'latitude', 'longitude', 'year', 'week_no', 'emission', 'day_of_week'])
exog.columns = list(range(70)) + ['id', 'date']
exog.insert(0, 'date', exog.pop('date'))
exog.insert(0, 'id', exog.pop('id'))
exog_groups = exog.groupby('id')

df_test = df_test.sort_values(['id', 'year', 'week_no']).drop(columns=['ID_LAT_LON_YEAR_WEEK', 'latitude', 'longitude', 'year', 'week_no'])
df_test.columns = ['id'] + list(range(70))
test_groups = df_test.groupby('id')

# %%
# function to create model and forecast
def autosarimax(endog, exog, exog_test, steps=49):
    if len(exog.columns) < 1:
        exog = None
        exog_test = None
    else:
        exog = exog.values
        exog_test = exog_test.values
    autosarimax = auto_arima(y = endog.loc[:, 'emission'].values,
                             X = exog)
    autosarimax = autosarimax.fit(y = endog.loc[:, 'emission'].values,
                                  X = exog,
                                  full_output = False,
                                  disp = False)
    return autosarimax.predict(n_periods = steps,
                               X = exog_test)

# %%
# %%time
# run sarimax function for every location
results = {}

for i, (name, endog_group) in enumerate(endog_groups):
    if i%10 == 0: print(f'{int(100*i/endog_groups.ngroups)} %')
    df_endog_id = endog_group.drop(columns='id').set_index('date', drop=True).resample('W').nearest()
    df_exog_id = exog_groups.get_group(name).drop(columns='id').set_index('date', drop=True).resample('W').nearest()
    df_exog_id = df_exog_id.loc[:, df_exog_id.isna().mean() < .1].interpolate().bfill().ffill()
    df_exog_id_test = test_groups.get_group(name).drop(columns='id').interpolate().bfill().ffill()#.set_index('date', drop=True).resample('W').nearest()
    df_exog_id_test = df_exog_id_test[df_exog_id.columns]
    test = autosarimax(df_endog_id, df_exog_id, df_exog_id_test)
    results[name] = test
df_results = pd.DataFrame(results).T.reset_index()
df_results
# Out:
# 0 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 2 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 4 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 6 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 8 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 10 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 12 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 14 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 16 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 18 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 20 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 22 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 24 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# 26 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 28 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 30 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# 32 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# ...
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# 92 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 94 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 96 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# 98 %
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# C:\Users\Andrew\miniconda3\envs\kaggle\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# CPU times: total: 3h 10min 39s
# Wall time: 3h 8min 59s
#                 index           0           1           2           3  \
# 0    ID_-0.510_29.290    3.578441    3.998130    4.177185    4.167426
# 1    ID_-0.528_29.472    3.984804    4.182931    3.794387    4.468849
# 2    ID_-0.547_29.653    0.511972    0.522355    0.596686    0.613425
# 3    ID_-0.569_30.031  110.993610  112.517735  117.647625  111.135845
# 4    ID_-0.598_29.102    0.085480    0.087547    0.092392    0.081485
# ..                ...         ...         ...         ...         ...
# 492  ID_-3.153_30.347   14.771227   16.417780   16.522413   14.349629
# 493  ID_-3.161_28.839    0.122746    0.124169    0.133911    0.125606
# 494  ID_-3.174_29.926   42.346913   42.285981   45.841601   40.493576
# 495  ID_-3.287_29.713   43.264049   42.891530   44.914488   41.052343
# 496  ID_-3.299_30.301   26.333874   29.561785   27.649085   25.783023
#
#               4           5           6           7           8           9  \
# 0      4.380077    4.410263    4.346310    4.093629    4.018802    4.302843
# 1      4.963955    4.309669    4.813111    4.477295    5.163820    4.848080
# 2      0.674077    0.661358    0.653126    0.626441    0.667443    0.673822
# 3    117.674962  112.308767  110.826259  122.380302  105.473930  117.228529
# 4      0.085885    0.080062    0.085516    0.083156    0.080923    0.098265
# ..          ...         ...         ...         ...         ...         ...
# 492   15.149342   13.634964   12.820321   14.846805   13.269030   14.953678
# 493    0.121393    0.119776    0.118752    0.119776    0.112136    0.127682
# 494   43.224044   41.960316   43.874106   40.126861   43.654071   45.980622
# 495   43.513073   42.854204   41.738109   42.445812   43.407929   41.601232
# 496   27.491349   26.547686   26.481294   27.463920   25.639051   28.070758
#
#              10          11          12          13          14          15  \
# 0      4.270852    4.317106    4.117228    3.856638    3.797460    4.285344
# 1      4.101785    4.858835    3.658950    4.699039    3.976310    4.252321
# 2      0.581000    0.664908    0.578348    0.587944    0.586660    0.648593
# 3    113.454748  119.181186  112.503494  114.803470  116.384686  119.260097
# 4      0.088652    0.098952    0.091285    0.078337    0.087735    0.090364
# ..          ...         ...         ...         ...         ...         ...
# 492   13.608090   14.520034   13.802129   13.907957   13.561242   12.105701
# 3    126.951907  138.604985  140.360496  140.071214  143.224885  154.730556
# 4      0.103478    0.110388    0.102518    0.105044    0.110086    0.104918
# ..          ...         ...         ...         ...         ...         ...
# 492   14.938079   15.141150   15.825469   16.356388   17.652048   17.024587
# 493    0.144937    0.145111    0.152352    0.151168    0.152128    0.151736
# 494   48.015970   46.462889   50.125700   50.764344   53.325260   53.034370
# 495   43.698109   44.787628   44.191529   45.252954   48.174869   49.840216
# 496   30.812468   30.467268   29.614359   30.620201   32.725163   32.881444
#
#              40          41          42          43          44          45  \
# 0      4.774278    4.963072    5.188317    5.451506    5.757096    5.462516
# 1      4.304752    4.820544    5.287675    4.846929    5.019035    4.928563
# 2      0.717498    0.734328    0.708342    0.755311    0.685724    0.683315
# 3    148.419830  148.638001  145.598175  154.136604  151.185232  147.363784
# 4      0.115314    0.120376    0.103367    0.117484    0.114189    0.115053
# ..          ...         ...         ...         ...         ...         ...
# 492   18.456084   19.171887   17.232205   18.666779   17.113953   17.694159
# 493    0.152105    0.156451    0.150387    0.163317    0.149865    0.148870
# 494   54.300570   53.141521   54.393315   52.970639   51.276391   52.294158
# 495   49.873961   55.786627   51.843995   52.428253   52.741911   48.473473
# 496   33.182872   37.911879   33.429805   32.162396   33.825590   32.572584
#
#               46          47          48
# 0      -2.998590    4.611031    4.720119
# 1      -1.015974    5.041680    5.299891
# 2       1.172501    0.700853    0.644634
# 3     136.829919  141.576474  146.710939
# 4       0.475769    0.113678    0.102089
# ..           ...         ...         ...
# 492 -1984.982464   16.968286   16.516575
# 493     0.108588    0.147977    0.140031
# 494    57.550376   48.892239   48.455388
# 495    44.545860   48.732581   49.193335
# 496  -750.872112   32.761105   31.838248
#
# [497 rows x 50 columns]

# %%
# format output
df_results = df_results.melt(id_vars=['index'], value_vars=range(49))
df_results['id'] = df_results['index'] + '_2022_' + df_results['variable'].astype('string').str.zfill(2)
df_results = df_results[['id', 'value']]
df_results = df_results.sort_values('id').reset_index(drop=True)
df_results.columns = ['ID_LAT_LON_YEAR_WEEK', 'emission']
df_results
# Out:
#            ID_LAT_LON_YEAR_WEEK    emission
# 0      ID_-0.510_29.290_2022_00    3.578441
# 1      ID_-0.510_29.290_2022_01    3.998130
# 2      ID_-0.510_29.290_2022_02    4.177185
# 3      ID_-0.510_29.290_2022_03    4.167426
# 4      ID_-0.510_29.290_2022_04    4.380077
# ...                         ...         ...
# 24348  ID_-3.299_30.301_2022_44   33.825590
# 24349  ID_-3.299_30.301_2022_45   32.572584
# 24350  ID_-3.299_30.301_2022_46 -750.872112
# 24351  ID_-3.299_30.301_2022_47   32.761105
# 24352  ID_-3.299_30.301_2022_48   31.838248
#
# [24353 rows x 2 columns]

# %%
# save output to csv
df_results.to_csv('output/autosarimax.csv', index=False)
