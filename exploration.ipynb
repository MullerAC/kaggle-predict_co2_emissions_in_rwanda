# %%
import pandas as pd

# %%
dtype = {'ID_LAT_LON_YEAR_WEEK':'string',
         'latitude': 'float',
         'longitude': 'float',
         'year': 'int',
         'week_no': 'int',
         'emission': 'float'}

# %%
df = pd.read_csv('files/train.csv', dtype=dtype)
df
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# 1      ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# 2      ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# 3      ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# 4      ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                         ...       ...        ...   ...      ...
# 79018  ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# 79019  ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# 79020  ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# 79021  ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# 79022  ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  string
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int32
#  4   week_no                                                   79023 non-null  int32
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %%
df.describe()
# Out:
#            latitude     longitude          year       week_no  \
# count  79023.000000  79023.000000  79023.000000  79023.000000
# mean      -1.891072     29.880155   2020.000000     26.000000
# std        0.694522      0.810375      0.816502     15.297155
# min       -3.299000     28.228000   2019.000000      0.000000
# 25%       -2.451000     29.262000   2019.000000     13.000000
# 50%       -1.882000     29.883000   2020.000000     26.000000
# 75%       -1.303000     30.471000   2021.000000     39.000000
# max       -0.510000     31.532000   2021.000000     52.000000
#
#        SulphurDioxide_SO2_column_number_density  \
# count                              64414.000000
# mean                                   0.000048
# std                                    0.000272
# min                                   -0.000996
# 25%                                   -0.000096
# 50%                                    0.000024
# 75%                                    0.000153
# ...

# %%
df.groupby(['latitude', 'longitude'])[['year', 'week_no']].count()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301      159      159
# -3.287   29.713      159      159
# -3.174   29.926      159      159
# -3.161   28.839      159      159
# -3.153   30.347      159      159
# ...                  ...      ...
# -0.598   29.102      159      159
# -0.569   30.031      159      159
# -0.547   29.653      159      159
# -0.528   29.472      159      159
# -0.510   29.290      159      159
#
# [497 rows x 2 columns]

# %%
df.groupby(['latitude', 'longitude'])[['year', 'week_no']].min()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301     2019        0
# -3.287   29.713     2019        0
# -3.174   29.926     2019        0
# -3.161   28.839     2019        0
# -3.153   30.347     2019        0
# ...                  ...      ...
# -0.598   29.102     2019        0
# -0.569   30.031     2019        0
# -0.547   29.653     2019        0
# -0.528   29.472     2019        0
# -0.510   29.290     2019        0
#
# [497 rows x 2 columns]

# %%
df.groupby(['latitude', 'longitude'])[['year', 'week_no']].max()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301     2021       52
# -3.287   29.713     2021       52
# -3.174   29.926     2021       52
# -3.161   28.839     2021       52
# -3.153   30.347     2021       52
# ...                  ...      ...
# -0.598   29.102     2021       52
# -0.569   30.031     2021       52
# -0.547   29.653     2021       52
# -0.528   29.472     2021       52
# -0.510   29.290     2021       52
#
# [497 rows x 2 columns]

# %%
df2 = pd.read_csv('files/test.csv', dtype=dtype)
df2
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2022_00    -0.510     29.290  2022        0
# 1      ID_-0.510_29.290_2022_01    -0.510     29.290  2022        1
# 2      ID_-0.510_29.290_2022_02    -0.510     29.290  2022        2
# 3      ID_-0.510_29.290_2022_03    -0.510     29.290  2022        3
# 4      ID_-0.510_29.290_2022_04    -0.510     29.290  2022        4
# ...                         ...       ...        ...   ...      ...
# 24348  ID_-3.299_30.301_2022_44    -3.299     30.301  2022       44
# 24349  ID_-3.299_30.301_2022_45    -3.299     30.301  2022       45
# 24350  ID_-3.299_30.301_2022_46    -3.299     30.301  2022       46
# 24351  ID_-3.299_30.301_2022_47    -3.299     30.301  2022       47
# 24352  ID_-3.299_30.301_2022_48    -3.299     30.301  2022       48
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                           NaN
# 1                                      0.000456
# ...

# %%
df2.groupby(['latitude', 'longitude'])[['year', 'week_no']].count()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301       49       49
# -3.287   29.713       49       49
# -3.174   29.926       49       49
# -3.161   28.839       49       49
# -3.153   30.347       49       49
# ...                  ...      ...
# -0.598   29.102       49       49
# -0.569   30.031       49       49
# -0.547   29.653       49       49
# -0.528   29.472       49       49
# -0.510   29.290       49       49
#
# [497 rows x 2 columns]

# %%
df2.groupby(['latitude', 'longitude'])[['year', 'week_no']].min()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301     2022        0
# -3.287   29.713     2022        0
# -3.174   29.926     2022        0
# -3.161   28.839     2022        0
# -3.153   30.347     2022        0
# ...                  ...      ...
# -0.598   29.102     2022        0
# -0.569   30.031     2022        0
# -0.547   29.653     2022        0
# -0.528   29.472     2022        0
# -0.510   29.290     2022        0
#
# [497 rows x 2 columns]

# %%
df2.groupby(['latitude', 'longitude'])[['year', 'week_no']].max()
# Out:
#                     year  week_no
# latitude longitude
# -3.299   30.301     2022       48
# -3.287   29.713     2022       48
# -3.174   29.926     2022       48
# -3.161   28.839     2022       48
# -3.153   30.347     2022       48
# ...                  ...      ...
# -0.598   29.102     2022       48
# -0.569   30.031     2022       48
# -0.547   29.653     2022       48
# -0.528   29.472     2022       48
# -0.510   29.290     2022       48
#
# [497 rows x 2 columns]

# %%
len(df), len(df2)
# Out:
# (79023, 24353)

# %% [markdown]
# need to forecast the next 49 (!) weeks
